# %% [markdown]
# <a href="https://colab.research.google.com/github/jumbokh/nknu-class/blob/main/opencv/colab_showimg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display
from PIL import Image
import cv2
im = cv2.imread("./input1.jpg")
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB) # Converting BGR to RGB
display(Image.fromarray(im))
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FB0AA662C90>
