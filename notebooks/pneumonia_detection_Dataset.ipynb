# %% [markdown]
# <a href="https://colab.research.google.com/github/jumbokh/nknu-class/blob/main/notebooks/pneumonia_detection_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install kaggle

# %%
# !cp drive/MyDrive/mri_process.py .
from mri_process import kaggle_download, process, show_img_mask, DataGenerator, prediction, tversky, tversky_loss, focal_tversky

# %%
import os
api_token = kaggle_download(key = "c4d41a81c81b0d00a23d02b975dc8467")
# !cp /content/kaggle.json /root/.kaggle
# !cp /content/kaggle.json /content/drive/MyDrive/
# !chmod 600 /root/.kaggle/kaggle.json

 
os.chdir('/content/drive/MyDrive')
os.rmdir('dataset')
os.mkdir('dataset')
os.chdir('/content/drive/MyDrive/dataset')
# !kaggle competitions download -c pneumonia-detection
#!kaggle datasets download -d mateuszbuda/lgg-mri-segmentation
#!kaggle competitions download -c facial-keypoints-detection
# !unzip pneumonia-detection.zip 
#clear()
del api_token
# Out:
# ...
#   0% 0.00/54.9k [00:00<?, ?B/s]
# 100% 54.9k/54.9k [00:00<00:00, 8.30MB/s]
# ...
#   0% 0.00/97.1k [00:00<?, ?B/s]
# 100% 97.1k/97.1k [00:00<00:00, 13.4MB/s]
# ...
#   0% 0.00/65.9k [00:00<?, ?B/s]
# 100% 65.9k/65.9k [00:00<00:00, 9.35MB/s]
# ...
#   0% 0.00/219k [00:00<?, ?B/s]
# 100% 219k/219k [00:00<00:00, 30.9MB/s]
# ...
#   0% 0.00/98.7k [00:00<?, ?B/s]
# 100% 98.7k/98.7k [00:00<00:00, 14.0MB/s]
# ...
#   0% 0.00/104k [00:00<?, ?B/s]
# 100% 104k/104k [00:00<00:00, 14.2MB/s]
# ...
#   0% 0.00/115k [00:00<?, ?B/s]
# 100% 115k/115k [00:00<00:00, 16.0MB/s]
# ...
#   0% 0.00/103k [00:00<?, ?B/s]
# 100% 103k/103k [00:00<00:00, 13.5MB/s]
# ...
#   0% 0.00/30.8k [00:00<?, ?B/s]
# 100% 30.8k/30.8k [00:00<00:00, 7.43MB/s]
# ...
#   0% 0.00/52.1k [00:00<?, ?B/s]
# 100% 52.1k/52.1k [00:00<00:00, 7.23MB/s]
# ...
#   0% 0.00/114k [00:00<?, ?B/s]
# 100% 114k/114k [00:00<00:00, 15.3MB/s]
# ...
#   0% 0.00/56.4k [00:00<?, ?B/s]
# 100% 56.4k/56.4k [00:00<00:00, 7.75MB/s]
# ...
#   0% 0.00/38.9k [00:00<?, ?B/s]
# 100% 38.9k/38.9k [00:00<00:00, 5.37MB/s]
# ...

# %%
#os.rmdir('/content/drive/MyDrive/Pneumonia')
#os.mkdir('/content/drive/MyDrive/Pneumonia')
os.chdir('/content/drive/MyDrive/Pneumonia')
# !kaggle kernels output aakashnain/beating-everything-with-depthwise-convolution -p /content/drive/MyDrive/Pneumonia
# Out:
# ...
# Kernel log downloaded to /content/drive/MyDrive/Pneumonia/beating-everything-with-depthwise-convolution.log
