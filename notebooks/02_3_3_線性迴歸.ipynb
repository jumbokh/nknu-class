# %% [markdown]
# <a href="https://colab.research.google.com/github/jumbokh/nknu-class/blob/main/notebooks/02_3_3_%E7%B7%9A%E6%80%A7%E8%BF%B4%E6%AD%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 線性迴歸求解

# %% [markdown]
# ## 範例1. 簡單線性迴歸
# ### $\begin{equation}y = wx + b\end{equation}$

# %%
# OLS 公式
from IPython.display import Image
Image('https://github.com/jumbokh/nknu-class/blob/main/docs/regression_wb.png')

# %% [markdown]
# ![](https://drive.google.com/file/d/10ud7nAbC9LjpGQFX91Q91DQO_A9inlFQ/view?usp=sharing)

# %%
# 使用 OLS 公式計算 w、b
# 載入套件
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd

# 載入資料集
df = pd.read_csv('./population.csv')

w = ((df['pop'] - df['pop'].mean()) * df['year']).sum() \
     / ((df['year'] - df['year'].mean())**2).sum()
b = df['pop'].mean() - w * df['year'].mean()

print(f'w={w}, b={b}')
# Out:
# w=0.061159358661557375, b=-116.35631056117687

# %%
# 使用 NumPy 的現成函數 polyfit()
coef = np.polyfit(df['year'], df['pop'], deg=1)
print(f'w={coef[0]}, b={coef[1]}')
# Out:
# w=0.061159358661554586, b=-116.35631056117121
