# %% [markdown]
# <a href="https://colab.research.google.com/github/jumbokh/nknu-class/blob/main/NLP/notebooks/BookData_DM2145.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -fs /content/gdrive/My\ Drive /app

# %%
# %cd /app
# !git clone https://github.com/mc6666/DL_Book
# Out:
# /content/gdrive/My Drive
# Cloning into 'DL_Book'...
# remote: Enumerating objects: 446, done.
# remote: Counting objects: 100% (240/240), done.
# remote: Compressing objects: 100% (236/236), done.
# remote: Total 446 (delta 107), reused 0 (delta 0), pack-reused 206
# Receiving objects: 100% (446/446), 110.88 MiB | 16.35 MiB/s, done.
# Resolving deltas: 100% (151/151), done.
# Checking out files: 100% (211/211), done.

# %%
# !ls /app/DL_Book
# Out:
#  data_download.md   src			  勘誤表.md
#  README.md	   'Tensorflow 安裝.md'   封面1.jpeg

# %%
# %cd /app/DL_Book
# !unzip data.zip
# Out:
# /content/gdrive/My Drive/DL_Book
# Archive:  data.zip
#    creating: audio/
#   inflating: audio/down.wav
#   inflating: audio/generated.wav
#   inflating: audio/man.wav
#  extracting: audio/random.wav
#   inflating: audio/record.wav
#   inflating: audio/WAV_1MG.wav
#   inflating: audio/WAV_1MG_mono.wav
#   inflating: audio/woman.wav
#    creating: cascade_files/
#   inflating: cascade_files/haarcascade_eye.xml
#   inflating: cascade_files/haarcascade_eye_tree_eyeglasses.xml
#   inflating: cascade_files/haarcascade_frontalcatface.xml
#   inflating: cascade_files/haarcascade_frontalcatface_extended.xml
#   inflating: cascade_files/haarcascade_frontalface_alt.xml
#   inflating: cascade_files/haarcascade_frontalface_alt2.xml
#   inflating: cascade_files/haarcascade_frontalface_alt_tree.xml
#   inflating: cascade_files/haarcascade_frontalface_default.xml
#   inflating: cascade_files/haarcascade_fullbody.xml
#   inflating: cascade_files/haarcascade_lefteye_2splits.xml
# ...
